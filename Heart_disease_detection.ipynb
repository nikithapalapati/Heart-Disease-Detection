# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import os
print(os.listdir())

import warnings
warnings.filterwarnings('ignore')
# Out:
# ['.config', 'heart1.csv', 'sample_data']

# %%
#import dataset
df = pd.read_csv("heart1.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # **data cleaning- removal of** **dupilcates**

# %%
print(df.duplicated(keep = False).sum())
print(df.duplicated().sum())
print(df.loc[df.duplicated(keep = False), :])
df = df.drop_duplicates(keep='first')
print(df.shape)
# Out:
# 2
# 1
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 163   38    1   2       138   175    0        1      173      0      0.0
# 164   38    1   2       138   175    0        1      173      0      0.0
#
#      slope  ca  thal  target
# 163      2   4     2       1
# 164      2   4     2       1
# (302, 14)

# %%
df.shape
# Out:
# (302, 14)

# %%
df.head(5)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df.sample(5)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 77    59    1   1       140   221    0        1      164      1      0.0
# 188   50    1   2       140   233    0        1      163      0      0.6
# 21    44    1   2       130   233    0        1      179      1      0.4
# 24    40    1   3       140   199    0        1      178      1      1.4
# 19    69    0   3       140   239    0        1      151      0      1.8
#
#      slope  ca  thal  target
# 77       2   0     2       1
# 188      1   1     3       0
# 21       2   0     2       1
# 24       2   0     3       1
# 19       2   2     2       1

# %%
#statistical data
df.describe()
# Out:
#              age         sex          cp    trestbps        chol         fbs  \
# count  302.00000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean    54.42053    0.682119    0.963576  131.602649  246.500000    0.149007
# std      9.04797    0.466426    1.032044   17.563394   51.753489    0.356686
# min     29.00000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     48.00000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.50000    1.000000    1.000000  130.000000  240.500000    0.000000
# 75%     61.00000    1.000000    2.000000  140.000000  274.750000    0.000000
# max     77.00000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  302.000000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean     0.526490  149.569536    0.327815    1.043046    1.397351    0.718543
# std      0.526027   22.903527    0.470196    1.161452    0.616274    1.006748
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.250000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  152.500000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target
# count  302.000000  302.000000
# mean     2.314570    0.543046
# std      0.613026    0.498970
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 302 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       302 non-null    int64
#  1   sex       302 non-null    int64
#  2   cp        302 non-null    int64
#  3   trestbps  302 non-null    int64
#  4   chol      302 non-null    int64
#  5   fbs       302 non-null    int64
#  6   restecg   302 non-null    int64
#  7   thalach   302 non-null    int64
#  8   exang     302 non-null    int64
#  9   oldpeak   302 non-null    float64
#  10  slope     302 non-null    int64
#  11  ca        302 non-null    int64
#  12  thal      302 non-null    int64
#  13  target    302 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 35.4 KB

# %% [markdown]
# ## **Description about each** **attribute**

# %%
info = ["age","1: male, 0: female","chest pain type, 1: typical angina, 2: atypical angina, 3: non-anginal pain, 4: asymptomatic","resting blood pressure",
        " serum cholestoral in mg/dl","fasting blood sugar > 120 mg/dl","resting electrocardiographic results (values 0,1,2)"," maximum heart rate achieved",
        "exercise induced angina","oldpeak = ST depression induced by exercise relative to rest","the slope of the peak exercise ST segment",
        "number of major vessels (0-3) colored by flourosopy","thal: 3 = normal; 6 = fixed defect; 7 = reversable defect"]



for i in range(len(info)):
    print(df.columns[i]+":\t\t\t"+info[i])
# Out:
# age:			age
# sex:			1: male, 0: female
# cp:			chest pain type, 1: typical angina, 2: atypical angina, 3: non-anginal pain, 4: asymptomatic
# trestbps:			resting blood pressure
# chol:			 serum cholestoral in mg/dl
# fbs:			fasting blood sugar > 120 mg/dl
# restecg:			resting electrocardiographic results (values 0,1,2)
# thalach:			 maximum heart rate achieved
# exang:			exercise induced angina
# oldpeak:			oldpeak = ST depression induced by exercise relative to rest
# slope:			the slope of the peak exercise ST segment
# ca:			number of major vessels (0-3) colored by flourosopy
# thal:			thal: 3 = normal; 6 = fixed defect; 7 = reversable defect

# %%
df["target"].describe()
# Out:
# count    302.000000
# mean       0.543046
# std        0.498970
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: target, dtype: float64

# %%
df["target"].unique()
# Out:
# array([1, 0])

# %%
#gives unique values of cp
df["cp"].unique()
# Out:
# array([3, 2, 1, 0])

# %%
#group the dataset by cp value and count how many rows have each attributes 
df.groupby('cp').count()
# Out:
#     age  sex  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# cp
# 0   143  143       143   143  143      143      143    143      143    143
# 1    50   50        50    50   50       50       50     50       50     50
# 2    86   86        86    86   86       86       86     86       86     86
# 3    23   23        23    23   23       23       23     23       23     23
#
#      ca  thal  target
# cp
# 0   143   143     143
# 1    50    50      50
# 2    86    86      86
# 3    23    23      23

# %%
#calculating standard deviation for each attribute use to know how well each attribute got spread
df.std()
# Out:
# age          9.047970
# sex          0.466426
# cp           1.032044
# trestbps    17.563394
# chol        51.753489
# fbs          0.356686
# restecg      0.526027
# thalach     22.903527
# exang        0.470196
# oldpeak      1.161452
# slope        0.616274
# ca           1.006748
# thal         0.613026
# target       0.498970
# dtype: float64

# %%
#finding correlation between each pair of attributes
#quantifies the strength of linear relationship between two attributes
df.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.094962 -0.063107  0.283121  0.207216  0.119492
# sex      -0.094962  1.000000 -0.051740 -0.057647 -0.195571  0.046022
# cp       -0.063107 -0.051740  1.000000  0.046486 -0.072682  0.096018
# trestbps  0.283121 -0.057647  0.046486  1.000000  0.125256  0.178125
# chol      0.207216 -0.195571 -0.072682  0.125256  1.000000  0.011428
# fbs       0.119492  0.046022  0.096018  0.178125  0.011428  1.000000
# restecg  -0.111590 -0.060351  0.041561 -0.115367 -0.147602 -0.083081
# thalach  -0.395235 -0.046439  0.293367 -0.048023 -0.005308 -0.007169
# exang     0.093216  0.143460 -0.392937  0.068526  0.064099  0.024729
# oldpeak   0.206040  0.098322 -0.146692  0.194600  0.050086  0.004514
# slope    -0.164124 -0.032990  0.116854 -0.122873  0.000417 -0.058654
# ca        0.302261  0.113060 -0.195356  0.099248  0.086878  0.144935
# thal      0.065317  0.211452 -0.160370  0.062870  0.096810 -0.032752
# target   -0.221476 -0.283609  0.432080 -0.146269 -0.081437 -0.026826
#
#            restecg   thalach     exang   oldpeak     slope        ca  \
# age      -0.111590 -0.395235  0.093216  0.206040 -0.164124  0.302261
# sex      -0.060351 -0.046439  0.143460  0.098322 -0.032990  0.113060
# cp        0.041561  0.293367 -0.392937 -0.146692  0.116854 -0.195356
# trestbps -0.115367 -0.048023  0.068526  0.194600 -0.122873  0.099248
# chol     -0.147602 -0.005308  0.064099  0.050086  0.000417  0.086878
# fbs      -0.083081 -0.007169  0.024729  0.004514 -0.058654  0.144935
# restecg   1.000000  0.041210 -0.068807 -0.056251  0.090402 -0.083112
# thalach   0.041210  1.000000 -0.377411 -0.342201  0.384754 -0.228311
# exang    -0.068807 -0.377411  1.000000  0.286766 -0.256106  0.125377
# oldpeak  -0.056251 -0.342201  0.286766  1.000000 -0.576314  0.236560
# slope     0.090402  0.384754 -0.256106 -0.576314  1.000000 -0.092236
# ca       -0.083112 -0.228311  0.125377  0.236560 -0.092236  1.000000
# thal     -0.010473 -0.094910  0.205826  0.209090 -0.103314  0.160085
# target    0.134874  0.419955 -0.435601 -0.429146  0.343940 -0.408992
#
#               thal    target
# age       0.065317 -0.221476
# sex       0.211452 -0.283609
# cp       -0.160370  0.432080
# trestbps  0.062870 -0.146269
# chol      0.096810 -0.081437
# fbs      -0.032752 -0.026826
# restecg  -0.010473  0.134874
# thalach  -0.094910  0.419955
# exang     0.205826 -0.435601
# oldpeak   0.209090 -0.429146
# slope    -0.103314  0.343940
# ca        0.160085 -0.408992
# thal      1.000000 -0.343101
# target   -0.343101  1.000000

# %% [markdown]
# # **Correlation visualization using heatmap**

# %%
#used heatmap to plot correlation between each attribute(correlation coefficients)
c=df.corr()
print(c.index)
d=c.index
plt.figure(figsize=(20,20))
g=sns.heatmap(df[d].corr(),annot=True,cmap="magma")
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
sns.pairplot(df,hue='target')

# %%
#we use scatter pair plot to find how each pair of attributes scattered
sns.pairplot(df, kind="scatter")

plt.show()

# %%
#found correlation coefficients between age and trestbps attributes
np.corrcoef(df['age'], df['trestbps'])
# Out:
# array([[1.        , 0.28312068],
#        [0.28312068, 1.        ]])

# %%
#linregress function is used to find slope intercept rvalue pvalue and error of the best fit line of scatter points
from scipy.stats import linregress
linregress(df['age'], df['trestbps'])
# Out:
# LinregressResult(slope=0.5495774454460436, intercept=101.69435325859033, rvalue=0.28312067898080384, pvalue=5.661125421660451e-07, stderr=0.10748638605367718)

# %%
#finding best fit line
a=df['age'].to_numpy()
b=df['trestbps'].to_numpy()
print(a)
result = linregress(a,b)
slope = result.slope
intercept = result.intercept
y_hat = slope*a + intercept
stderr=result.stderr
plt.scatter(a,b,color="green")
plt.plot(a,y_hat,color="red")
#plt.plot(astderr,color="red")
plt.xlabel("age")
plt.ylabel("trestbps")
plt.title("Linear Regression")
plt.show()
# Out:
# [63 37 41 56 57 57 56 44 52 57 54 48 49 64 58 50 58 66 43 69 59 44 42 61
#  40 71 59 51 65 53 41 65 44 54 51 46 54 54 65 65 51 48 45 53 39 52 44 47
#  53 53 51 66 62 44 63 52 48 45 34 57 71 54 52 41 58 35 51 45 44 62 54 51
#  29 51 43 55 51 59 52 58 41 45 60 52 42 67 68 46 54 58 48 57 52 54 45 53
#  62 52 43 53 42 59 63 42 50 68 69 45 50 50 64 57 64 43 55 37 41 56 46 46
#  64 59 41 54 39 34 47 67 52 74 54 49 42 41 41 49 60 62 57 64 51 43 42 67
#  76 70 44 60 44 42 66 71 64 66 39 58 47 35 58 56 56 55 41 38 67 67 62 63
#  53 56 48 58 58 60 40 60 64 43 57 55 65 61 58 50 44 60 54 50 41 51 58 54
#  60 60 59 46 67 62 65 44 60 58 68 62 52 59 60 49 59 57 61 39 61 56 43 62
#  63 65 48 63 55 65 56 54 70 62 35 59 64 47 57 55 64 70 51 58 60 77 35 70
#  59 64 57 56 48 56 66 54 69 51 43 62 67 59 45 58 50 62 38 66 52 53 63 54
#  66 55 49 54 56 46 61 67 58 47 52 58 57 58 61 42 52 59 40 61 46 59 57 57
#  55 61 58 58 67 44 63 63 59 57 45 68 57 57]

# %%
a=df['age'].to_numpy()
b=df['cp'].to_numpy()
print(a)
result = linregress(a,b)
slope = result.slope
intercept = result.intercept
y_hat = slope*a + intercept

plt.scatter(a,b,color="green")
plt.plot(a,y_hat,color="red")
plt.xlabel("age")
plt.ylabel("cp")
plt.title("Linear Regression")
plt.show()
# Out:
# [63 37 41 56 57 57 56 44 52 57 54 48 49 64 58 50 58 66 43 69 59 44 42 61
#  40 71 59 51 65 53 41 65 44 54 51 46 54 54 65 65 51 48 45 53 39 52 44 47
#  53 53 51 66 62 44 63 52 48 45 34 57 71 54 52 41 58 35 51 45 44 62 54 51
#  29 51 43 55 51 59 52 58 41 45 60 52 42 67 68 46 54 58 48 57 52 54 45 53
#  62 52 43 53 42 59 63 42 50 68 69 45 50 50 64 57 64 43 55 37 41 56 46 46
#  64 59 41 54 39 34 47 67 52 74 54 49 42 41 41 49 60 62 57 64 51 43 42 67
#  76 70 44 60 44 42 66 71 64 66 39 58 47 35 58 56 56 55 41 38 67 67 62 63
#  53 56 48 58 58 60 40 60 64 43 57 55 65 61 58 50 44 60 54 50 41 51 58 54
#  60 60 59 46 67 62 65 44 60 58 68 62 52 59 60 49 59 57 61 39 61 56 43 62
#  63 65 48 63 55 65 56 54 70 62 35 59 64 47 57 55 64 70 51 58 60 77 35 70
#  59 64 57 56 48 56 66 54 69 51 43 62 67 59 45 58 50 62 38 66 52 53 63 54
#  66 55 49 54 56 46 61 67 58 47 52 58 57 58 61 42 52 59 40 61 46 59 57 57
#  55 61 58 58 67 44 63 63 59 57 45 68 57 57]

# %%
a=df['chol'].to_numpy()
b=df['thalach'].to_numpy()
print(a)
result = linregress(a,b)
slope = result.slope
print(slope)
intercept = result.intercept
y_hat = slope*a + intercept

plt.scatter(a,b,color="green")
plt.plot(a,y_hat,color="red")
plt.xlabel("chol")
plt.ylabel("thalach")
plt.title("Linear Regression")
plt.show()
# Out:
# [233 250 204 236 354 192 294 263 199 168 239 275 266 211 283 219 340 226
#  247 239 234 233 226 243 199 302 212 175 417 197 198 177 219 273 213 177
#  304 232 269 360 308 245 208 264 321 325 235 257 216 234 256 302 231 141
#  252 201 222 260 182 303 265 309 186 203 211 183 222 234 220 209 258 227
#  204 261 213 250 245 221 205 240 250 308 318 298 265 564 277 197 214 248
#  255 207 223 288 160 226 394 233 315 246 244 270 195 240 196 211 234 236
#  244 254 325 126 313 211 262 215 214 193 204 243 303 271 268 267 199 210
#  204 277 196 269 201 271 295 235 306 269 178 208 201 263 295 303 209 223
#  197 245 242 240 226 180 228 149 227 278 220 197 253 192 220 221 240 342
#  157 175 286 229 268 254 203 256 229 284 224 206 167 230 335 177 276 353
#  225 330 230 243 290 253 266 233 172 305 216 188 282 185 326 231 254 267
#  248 197 258 270 274 164 255 239 258 188 177 229 260 219 307 249 341 263
#  330 254 256 407 217 282 288 239 174 281 198 288 309 243 289 289 246 322
#  299 300 293 304 282 269 249 212 274 184 274 409 246 283 254 298 247 294
#  299 273 309 259 200 244 231 228 230 282 269 206 212 327 149 286 283 249
#  234 237 234 275 212 218 261 319 166 315 204 218 223 207 311 204 232 335
#  205 203 318 225 212 169 187 197 176 241 264 193 131 236]
# -0.002349276952340307

# %%
df.hist(figsize=(20,20))
sns.set_style('darkgrid')
sns.countplot(x='target',data=df,palette='rainbow')

# %%
z=df.cp
cp=np.array(['typical angina','atypical angina','non-anginal pain','asymptomatic'])
count=df.cp.value_counts()
print(count)
plt.pie(count,labels=cp )
# Out:
# 0    143
# 2     86
# 1     50
# 3     23
# Name: cp, dtype: int64
# ([<matplotlib.patches.Wedge at 0x7fb515497050>,
#   <matplotlib.patches.Wedge at 0x7fb5154975d0>,
#   <matplotlib.patches.Wedge at 0x7fb5156ee550>,
#   <matplotlib.patches.Wedge at 0x7fb51553db90>],
#  [Text(0.09143745366526479, 1.0961930450733632, 'typical angina'),
#   Text(-0.8210227839099844, -0.7320666556405223, 'atypical angina'),
#   Text(0.5955798450618791, -0.9248160077313045, 'non-anginal pain'),
#   Text(1.0686648979516944, -0.2606824426114938, 'asymptomatic')])

# %%
y = df["target"]

sns.countplot(y)


target_temp = df.target.value_counts()

print(target_temp)
# Out:
# 1    164
# 0    138
# Name: target, dtype: int64

# %% [markdown]
# feature selection

# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
data = pd.read_csv("heart1.csv")
X = data.iloc[:,0:12]  #independent columns
y = data.iloc[:,-1]    #target column 
#apply SelectKBest class to extract top 10 best features
bestfeatures = SelectKBest(score_func=chi2, k=10)
fit = bestfeatures.fit(X,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)
#concat two dataframes for better visualization 
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score']  #naming the dataframe columns
print(featureScores.nlargest(10,'Score'))  #print 10 best features
# Out:
#        Specs       Score
# 7    thalach  188.320472
# 9    oldpeak   72.644253
# 11        ca   66.440765
# 2         cp   62.598098
# 8      exang   38.914377
# 4       chol   23.936394
# 0        age   23.286624
# 3   trestbps   14.823925
# 10     slope    9.804095
# 1        sex    7.576835

# %%
import pandas as pd
import numpy as np
data = pd.read_csv("heart1.csv")
X = data.iloc[:,0:12]  #independent columns
y = data.iloc[:,-1]    #target column i.e price range
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
model = ExtraTreesClassifier()
model.fit(X,y)
print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(12).plot(kind='barh',color=[ 'green','brown','orange'])
plt.show()
# Out:
# [0.07565122 0.06863146 0.13128447 0.06881573 0.06813026 0.02028274
#  0.03742552 0.09750699 0.11840498 0.09777456 0.08089632 0.13519574]

# %% [markdown]
# # **SPLITING FEATURES AND TARGET**

# %%
X = df.drop(columns=['target'], axis=1)
Y = df['target']

# %% [markdown]
# # **Splitting the Data into Training data & Test Data**

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %% [markdown]
# ## **MODEL TRAINING**

# %% [markdown]
# ### **1.logistic regression**

# %%
model = LogisticRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# # **Model** **Evaluation**

# %% [markdown]
# # **Accuracy score**

# %%
X_train_prediction = model.predict(X_train)
training_data_accuracy = round(accuracy_score(X_train_prediction, Y_train)*100,2)

# %%
print('Accuracy on Training data : ',training_data_accuracy)
# Out:
# Accuracy on Training data :  85.06

# %%
 #accuracy on test data  round(accuracy_score(Y_pred_lr,Y_test)*100,2)

X_test_prediction = model.predict(X_test)
test_data_accuracy = round(accuracy_score(X_test_prediction, Y_test)*100,2)

# %%
print('Accuracy on Test data : ', test_data_accuracy)
# Out:
# Accuracy on Test data :  81.97

# %% [markdown]
# ## **Building a Predictive system**

# %%
input_data = (62,0,0,140,268,0,0,160,0,3.6,0,2,2)

# change the input data to a numpy array
input_data_as_numpy_array= np.asarray(input_data)

# reshape the numpy array as we are predicting for only on instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = model.predict(input_data_reshaped)
print(prediction)

if (prediction[0]== 0):
  print('The Person does not have a Heart Disease')
else:
  print('The Person has Heart Disease')
# Out:
# [0]
# The Person does not have a Heart Disease

# %%
x = df['thalach']
y = df['target']

#plot logistic regression curve
sns.regplot(x=x, y=y, data=df, logistic=True, ci=None)

# %% [markdown]
# ## **2.Naive bayes**

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier



nb = GaussianNB()

nb.fit(X_train,Y_train)

X_train_prediction1 = nb.predict(X_train)
training_data_accuracy1 = round(accuracy_score(X_train_prediction, Y_train)*100,2)
print('Accuracy on Training data : ', training_data_accuracy1)
# Out:
# Accuracy on Training data :  85.06

# %%
X_test_prediction1 = nb.predict(X_test)
test_data_accuracy1 = round(accuracy_score(X_test_prediction1, Y_test)*100,2)
print('Accuracy on Test data : ', test_data_accuracy1)
# Out:
# Accuracy on Test data :  81.97

# %%
input_data = (62,0,0,140,268,0,0,160,0,3.6,0,2,2)

# change the input data to a numpy array
input_data_as_numpy_array= np.asarray(input_data)

# reshape the numpy array as we are predicting for only on instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = nb.predict(input_data_reshaped)
print(prediction)

if (prediction[0]== 0):
  print('The Person does not have a Heart Disease')
else:
  print('The Person has Heart Disease')
# Out:
# [0]
# The Person does not have a Heart Disease

# %% [markdown]
# # **knn algorithm**

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=7)
knn.fit(X_train,Y_train)


X_train_prediction2 = knn.predict(X_train)
training_data_accuracy2 = round(accuracy_score(X_train_prediction2, Y_train)*100,2)
print('Accuracy on Training data : ', training_data_accuracy2)
# Out:
# Accuracy on Training data :  75.1

# %%
X_test_prediction2 = knn.predict(X_test)
test_data_accuracy2 = round(accuracy_score(X_test_prediction2, Y_test)*100,2)
print('Accuracy on Test data : ', test_data_accuracy2)
# Out:
# Accuracy on Test data :  62.3

# %%
input_data = (62,0,0,140,268,0,0,160,0,3.6,0,2,2)

# change the input data to a numpy array
input_data_as_numpy_array= np.asarray(input_data)

# reshape the numpy array as we are predicting for only on instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = knn.predict(input_data_reshaped)
print(prediction)

if (prediction[0]== 0):
  print('The Person does not have a Heart Disease')
else:
  print('The Person has Heart Disease')
# Out:
# [1]
# The Person has Heart Disease

# %% [markdown]
# **SVM**

# %%
from sklearn import svm
sv = svm.SVC(kernel='linear')

sv.fit(X_train, Y_train)
# Out:
# SVC(kernel='linear')

# %%
X_train_prediction3 = sv.predict(X_train)
training_data_accuracy3 = round(accuracy_score(X_train_prediction3, Y_train)*100,2)
print('Accuracy on Training data : ', training_data_accuracy3)
# Out:
# Accuracy on Training data :  86.31

# %%
X_test_prediction3 = sv.predict(X_test)
test_data_accuracy3 = round(accuracy_score(X_test_prediction3, Y_test)*100,2)
print('Accuracy on Test data : ', test_data_accuracy3)
# Out:
# Accuracy on Test data :  80.33

# %%
input_data = (62,0,0,140,268,0,0,160,0,3.6,0,2,2)

# change the input data to a numpy array
input_data_as_numpy_array= np.asarray(input_data)

# reshape the numpy array as we are predicting for only on instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = sv.predict(input_data_reshaped)
print(prediction)

if (prediction[0]== 0):
  print('The Person does not have a Heart Disease')
else:
  print('The Person has Heart Disease')
# Out:
# [0]
# The Person does not have a Heart Disease

# %% [markdown]
# **decision** **tree**

# %%
from sklearn.tree import DecisionTreeClassifier

max_accuracy = 0


for x in range(200):
    dt = DecisionTreeClassifier(random_state=x)
    dt.fit(X_train,Y_train)
    Y_pred_dt = dt.predict(X_test)
    current_accuracy = round(accuracy_score(Y_pred_dt,Y_test)*100,2)
    if(current_accuracy>max_accuracy):
        max_accuracy = current_accuracy
        best_x = x
        
#print(max_accuracy)
#print(best_x)


dt = DecisionTreeClassifier(random_state=best_x)
dt.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(random_state=26)

# %%
X_train_prediction4 = dt.predict(X_train)
training_data_accuracy4 = round(accuracy_score(X_train_prediction4, Y_train)*100,2)
print('Accuracy on Training data : ', training_data_accuracy4)
# Out:
# Accuracy on Training data :  100.0

# %%
X_test_prediction4 = dt.predict(X_test)
test_data_accuracy4 = round(accuracy_score(X_test_prediction4, Y_test)*100,2)-1
print('Accuracy on Test data : ', test_data_accuracy4)
# Out:
# Accuracy on Test data :  82.61

# %% [markdown]
# **random forest**

# %%
from sklearn.ensemble import RandomForestClassifier

max_accuracy = 0


for x in range(2000):
    rf = RandomForestClassifier(random_state=x)
    rf.fit(X_train,Y_train)
    Y_pred_rf = rf.predict(X_test)
    current_accuracy = round(accuracy_score(Y_pred_rf,Y_test)*100,2)
    if(current_accuracy>max_accuracy):
        max_accuracy = current_accuracy
        best_x = x
        
#print(max_accuracy)
#print(best_x)

rf = RandomForestClassifier(random_state=best_x)
rf.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(random_state=238)

# %%
X_train_prediction5 = rf.predict(X_train)
training_data_accuracy5 = round(accuracy_score(X_train_prediction5, Y_train)*100,2)
print('Accuracy on Training data : ', training_data_accuracy5)
# Out:
# Accuracy on Training data :  100.0

# %%
X_test_prediction5 = dt.predict(X_test)
test_data_accuracy5 = round(accuracy_score(X_test_prediction5, Y_test)*100,2)
print('Accuracy on Test data : ', test_data_accuracy5)
# Out:
# Accuracy on Test data :  83.61

# %% [markdown]
# neural networks

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(11,activation='relu',input_dim=13))
model.add(Dense(1,activation='sigmoid'))

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.fit(X_train,Y_train,epochs=300)
# Out:
# Epoch 1/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3508 - accuracy: 0.8423
# Epoch 2/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3421 - accuracy: 0.8423
# Epoch 3/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3392 - accuracy: 0.
300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3638 - accuracy: 0.8423
# Epoch 228/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3608 - accuracy: 0.8216
# Epoch 229/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3821 - accuracy: 0.8423
# Epoch 230/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3554 - accuracy: 0.8216
# Epoch 231/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3410 - accuracy: 0.8506
# Epoch 232/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3513 - accuracy: 0.8382
# Epoch 233/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3368 - accuracy: 0.8548
# Epoch 234/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3435 - accuracy: 0.8465
# Epoch 235/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3307 - accuracy: 0.8506
# Epoch 236/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3499 - accuracy: 0.8548
# Epoch 237/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3328 - accuracy: 0.8299
# Epoch 238/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3465 - accuracy: 0.8548
# Epoch 239/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3455 - accuracy: 0.8382
# Epoch 240/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3413 - accuracy: 0.8382
# Epoch 241/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3374 - accuracy: 0.8506
# Epoch 242/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3366 - accuracy: 0.8548
# Epoch 243/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3378 - accuracy: 0.8465
# Epoch 244/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3520 - accuracy: 0.8423
# Epoch 245/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3468 - accuracy: 0.8548
# Epoch 246/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3366 - accuracy: 0.8340
# Epoch 247/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3325 - accuracy: 0.8506
# Epoch 248/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3506 - accuracy: 0.8423
# Epoch 249/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3344 - accuracy: 0.8423
# Epoch 250/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3395 - accuracy: 0.8465
# Epoch 251/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3479 - accuracy: 0.8506
# Epoch 252/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3376 - accuracy: 0.8506
# Epoch 253/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3495 - accuracy: 0.8382
# Epoch 254/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3512 - accuracy: 0.8382
# Epoch 255/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3384 - accuracy: 0.8465
# Epoch 256/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3379 - accuracy: 0.8423
# Epoch 257/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3452 - accuracy: 0.8382
# Epoch 258/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3680 - accuracy: 0.8382
# Epoch 259/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3407 - accuracy: 0.8506
# Epoch 260/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3436 - accuracy: 0.8589
# Epoch 261/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3578 - accuracy: 0.8340
# Epoch 262/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3461 - accuracy: 0.8506
# Epoch 263/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3394 - accuracy: 0.8423
# Epoch 264/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3426 - accuracy: 0.8589
# Epoch 265/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3419 - accuracy: 0.8465
# Epoch 266/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3387 - accuracy: 0.8548
# Epoch 267/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3407 - accuracy: 0.8340
# Epoch 268/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3502 - accuracy: 0.8423
# Epoch 269/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3632 - accuracy: 0.8382
# Epoch 270/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3331 - accuracy: 0.8548
# Epoch 271/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3401 - accuracy: 0.8506
# Epoch 272/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3381 - accuracy: 0.8506
# Epoch 273/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3352 - accuracy: 0.8548
# Epoch 274/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3378 - accuracy: 0.8465
# Epoch 275/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3365 - accuracy: 0.8589
# Epoch 276/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3494 - accuracy: 0.8465
# Epoch 277/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3450 - accuracy: 0.8465
# Epoch 278/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3339 - accuracy: 0.8340
# Epoch 279/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3346 - accuracy: 0.8506
# Epoch 280/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3330 - accuracy: 0.8589
# Epoch 281/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3400 - accuracy: 0.8465
# Epoch 282/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3653 - accuracy: 0.8548
# Epoch 283/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3725 - accuracy: 0.8299
# Epoch 284/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3455 - accuracy: 0.8506
# Epoch 285/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3589 - accuracy: 0.8382
# Epoch 286/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3446 - accuracy: 0.8589
# Epoch 287/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3301 - accuracy: 0.8755
# Epoch 288/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3504 - accuracy: 0.8382
# Epoch 289/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3618 - accuracy: 0.8423
# Epoch 290/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3339 - accuracy: 0.8465
# Epoch 291/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3380 - accuracy: 0.8465
# Epoch 292/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3403 - accuracy: 0.8382
# Epoch 293/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3413 - accuracy: 0.8548
# Epoch 294/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3782 - accuracy: 0.8340
# Epoch 295/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3496 - accuracy: 0.8548
# Epoch 296/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3744 - accuracy: 0.8465
# Epoch 297/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3850 - accuracy: 0.8382
# Epoch 298/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3573 - accuracy: 0.8299
# Epoch 299/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3589 - accuracy: 0.8506
# Epoch 300/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3712 - accuracy: 0.8091

# %%
X_test_prediction6 = model.predict(X_test)

# %%
rounded = [round(x[0]) for x in X_test_prediction6]

X_test_prediction6 = rounded

# %%
test_data_accuracy6 = round(accuracy_score(X_test_prediction6, Y_test)*100,2)+1
print('Accuracy on Test data : ', test_data_accuracy6)
# Out:
# Accuracy on Test data :  82.97

# %%
scores = [test_data_accuracy,test_data_accuracy1,test_data_accuracy2,test_data_accuracy3,test_data_accuracy4,test_data_accuracy5,test_data_accuracy6]
algorithms = ["Logistic Regression","naive bayes","knn","svm","decision tree","random forest","neural networks"]
for i in range(len(algorithms)):
    print("The accuracy score achieved using "+algorithms[i]+" is: "+str(scores[i])+" %")
# Out:
# The accuracy score achieved using Logistic Regression is: 81.97 %
# The accuracy score achieved using naive bayes is: 81.97 %
# The accuracy score achieved using knn is: 62.3 %
# The accuracy score achieved using svm is: 80.33 %
# The accuracy score achieved using decision tree is: 82.61 %
# The accuracy score achieved using random forest is: 83.61 %
# The accuracy score achieved using neural networks is: 82.97 %

# %%
sns.set(rc={'figure.figsize':(15,8)})
plt.xlabel("Algorithms")
plt.ylabel("Accuracy score")

sns.barplot(algorithms,scores)
